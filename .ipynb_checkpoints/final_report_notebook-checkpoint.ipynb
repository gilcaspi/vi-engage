# %% [markdown]
# # Increasing WellCo Retention Rate with Vi Engage

# %%
from utils.data_loaders import get_features_df, get_churn_labels_df

# %%
import argparse
import os
from typing import List, Optional

import joblib
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go
from artifacts import ARTIFACTS_DIRECTORY_PATH
from compose.build_pipelines import build_supervised_pipeline
from data.raw.raw_data_column_names import MEMBER_ID_COLUMN, OUTREACH_COLUMN, CHURN_COLUMN, SIGNUP_DATE_COLUMN
from preprocessing.members_matching import matching_members, fit_propensity_model, match_on_propensity, \
    validate_matching_quality
from utils.data_loaders import get_features_df, get_churn_labels_df
from sklift.models.models import TwoModels
from xgboost import XGBClassifier

import plotly.io as pio

from utils.explain_model import plot_logistic_regression_importance
from utils.plot_utils import plot_feature_correlation_heatmap, plot_calibration_curve, plot_uplift_at_k_trend

from utils.metrics import c_for_benefit_from_pairs, qini_auc

# %%
pio.renderers.default = "notebook_connected"

# %%
features_version = 'v2'

# %%
features_df = get_features_df(features_version=features_version)
churn_labels_df = get_churn_labels_df()

# %%
features_with_labels = features_df.merge(
    churn_labels_df,
    on=MEMBER_ID_COLUMN,
    how='left'
)

# %%
X = features_with_labels.drop(
    columns=[
        MEMBER_ID_COLUMN,
        OUTREACH_COLUMN,
        CHURN_COLUMN,
        SIGNUP_DATE_COLUMN,
    ],
    errors="ignore",
)
y = features_with_labels[CHURN_COLUMN]
t = features_with_labels[OUTREACH_COLUMN]
stratify_col = features_with_labels[[CHURN_COLUMN, OUTREACH_COLUMN]].astype(int).astype(str).agg('_'.join, axis=1)

# %%
X_train, X_test, y_train, y_test, t_train, t_test = train_test_split(
    X, y, t,
    test_size=0.2,
    stratify=stratify_col,
    random_state=42
)

# %%
X_train_m, t_train_m, y_train_m, matched_idx_train, pairs_train = matching_members(X_train, t_train, y_train)
# Out:
# Matched train size: 3862 (pairs: 1931, treated: 1931, control: 1931)

# %%
plot_feature_correlation_heatmap(X_train_m, "Correlation Heatmap - Matched Train Set")

# %% [markdown]
# ## Churn Risk Estimator

# %%
baseline_model_name = f'baseline_logistic_regression_model'

baseline_pipeline = build_supervised_pipeline()
baseline_pipeline.fit(X_train_m, y_train_m)

y_test_churn_pred = baseline_pipeline.predict(X_test)
y_test_churn_proba = baseline_pipeline.predict_proba(X_test)[:, 1]

y_train_m_churn_proba = baseline_pipeline.predict_proba(X_train_m)[:, 1]

# %%
print("-" * 80)
print("Baseline Churn Risk Model Evaluation on Test Set: ")
print("ROC AUC:", roc_auc_score(y_test, y_test_churn_proba))
print(classification_report(y_test, y_test_churn_pred))
print("- - " * 20)
print("Baseline Churn Risk Model Evaluation on Train Set: ")
print("ROC AUC:", roc_auc_score(y_train_m, y_train_m_churn_proba))
print("-" * 80)
# Out:
# --------------------------------------------------------------------------------
# Baseline Churn Risk Model Evaluation on Test Set:
# ROC AUC: 0.6162252876724316
#               precision    recall  f1-score   support
#
#            0       0.84      0.64      0.73      1588
#            1       0.27      0.53      0.36       403
#
#     accuracy                           0.62      1991
#    macro avg       0.56      0.58      0.54      1991
# weighted avg       0.73      0.62      0.65      1991
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Baseline Churn Risk Model Evaluation on Train Set:
# ROC AUC: 0.6875214377976566
# --------------------------------------------------------------------------------

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.64      0.73      1588
#            1       0.27      0.53      0.36       403
#
#     accuracy                           0.62      1991
#    macro avg       0.56      0.58      0.54      1991
# weighted avg       0.73      0.62      0.65      1991

# %%
importance_df, fig = plot_logistic_regression_importance(
    model=baseline_pipeline,
    X_train=X_train_m,
    output_dir=os.path.join(ARTIFACTS_DIRECTORY_PATH, "explainability"),
    top_n=30,
    model_name="baseline_logistic_regression"
)
fig
# Out:
# Saved logistic regression feature importances to: C:\Users\labca\PycharmProjects\vi-demo\artifacts\explainability\baseline_logistic_regression_feature_importance.csv
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.2.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="15f5a312-fb83-4736-b6f5-5797a3ad6634" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("15f5a312-fb83-4736-b6f5-5797a3ad6634")) {                    Plotly.newPlot(                        "15f5a312-fb83-4736-b6f5-5797a3ad6634",                        [{"hovertemplate":"Absolute Coefficient (Importance)=%{x}\u003cbr\u003eFeature=%{y}\u003cbr\u003eCoefficient=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"+MiPzNj06L928ye61WPmP6CU3skkOuK\u002fP232KucY4D9URxI3YxnfP+NvxIEXVd2\u002fKMpwhsVT3T+5+MZefpPbvwB9sa8c9di\u002fRBU5rty02L\u002fNoOdWysfWPz6y1p2\u002fh9Y\u002fd9sMA4JF1b\u002fBOBGV1xTUPxfumlYoDtQ\u002f+GJLC126079cEsySHMrSP2KIIi8yONI\u002fiycXc29y0b+PuxM3Jd3Qv7L2EckTutA\u002fGt9gMg1i0L9jE4CyKtvOPz6n3\u002fKvSc4\u002fN0vj+Njdy7+VH2f3WLXLvzYMMaK\u002f7sq\u002fni6NNp26yr\u002fAx2PvMx7KP4n5tveyPMk\u002f"},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"+MiPzNj06D928ye61WPmP6CU3skkOuI\u002fP232KucY4D9URxI3YxnfP+NvxIEXVd0\u002fKMpwhsVT3T+5+MZefpPbPwB9sa8c9dg\u002fRBU5rty02D\u002fNoOdWysfWPz6y1p2\u002fh9Y\u002fd9sMA4JF1T\u002fBOBGV1xTUPxfumlYoDtQ\u002f+GJLC1260z9cEsySHMrSP2KIIi8yONI\u002fiycXc29y0T+PuxM3Jd3QP7L2EckTutA\u002fGt9gMg1i0D9jE4CyKtvOPz6n3\u002fKvSc4\u002fN0vj+Njdyz+VH2f3WLXLPzYMMaK\u002f7so\u002fni6NNp26yj\u002fAx2PvMx7KP4n5tveyPMk\u002f"},"xaxis":"x","y":["web_semcat_desc_league-highlights_desc-highlights","web_semcat_active_days_desc_league-highlights_desc-highlights","web_semcat_active_days_sleep-nutrition-hygiene","web_semcat_obedience-training_desc-pets","web_semcat_sleep-nutrition-hygiene","web_semcat_active_days_obedience-training_desc-pets","web_semcat_has_obedience-training_desc-pets","web_semcat_freq_per_active_day_obedience-training_desc-pets","web_semcat_title_electric-range-desc_charging","total_app_sessions","web_semcat_freq_per_active_day_desc_strategy-reviews_desc-reviews","web_semcat_box_office-releases-office_trailers","web_semcat_wellness-guide-exercise","web_semcat_has_sleep-nutrition-hygiene","web_semcat_active_days_title_electric-range-desc_charging","unique_wellco_web_active_days","web_semcat_freq_per_active_day_desc_league-highlights_desc-highlights","web_semcat_has_box_office-releases-office_trailers","web_semcat_desc_strategy-reviews_desc-reviews","web_semcat_has_desc_strategy-reviews_desc-reviews","web_semcat_active_days_desc_strategy-reviews_desc-reviews","web_semcat_has_desc_league-highlights_desc-highlights","web_semcat_active_days_desc_smartphones-gadget_roundup-smartphones","web_semcat_freq_per_active_day_desc_smartphones-gadget_roundup-smartphones","web_semcat_active_days_lifestyle_changes-lifestyle-changes","web_semcat_has_desc_smartphones-gadget_roundup-smartphones","web_semcatpct_wellness-guide-exercise","web_semcat_freq_per_active_day_box_office-releases-office_trailers","web_semcat_freq_per_active_day_wellness-guide-exercise","unique_app_active_days"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"co ...

# %%
plot_calibration_curve(
    y_ground_truth=y_test,
    y_estimated_probability=y_test_churn_proba,
    model_name=baseline_model_name,
)

# %%
predicted_churn_probabilities_all = pd.DataFrame({
    MEMBER_ID_COLUMN: features_with_labels[MEMBER_ID_COLUMN],
    "churn_prob": baseline_pipeline.predict_proba(X)[:, 1]
})
predicted_churn_probabilities_all.sort_values(by='churn_prob', ascending=False, inplace=True)
predicted_churn_probabilities_all
# Out:
#       member_id  churn_prob
# 5653       5683    0.953794
# 8679       8726    0.916001
# 4859       4887    0.910301
# 8858       8905    0.909164
# 8083       8129    0.905653
# ...         ...         ...
# 2481       2496    0.062625
# 8979       9026    0.057870
# 987         995    0.052662
# 5593       5622    0.050577
# 1712       1723    0.047233
#
# [9953 rows x 2 columns]

# %% [markdown]
# ## Uplift

# %% [markdown]
# ## Baseline Uplift Model

# %%
treatment_pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        max_iter=1000,
        class_weight='balanced',
    ),
)

control_pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        max_iter=1000,
        class_weight='balanced',
    ),
)

# %%
treatment_pipeline.fit(
    X_train_m[t_train_m == 1],
    y_train_m[t_train_m == 1],
)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
control_pipeline.fit(
    X_train_m[t_train_m == 0],
    y_train_m[t_train_m == 0],
)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
treatment_proba_test = treatment_pipeline.predict_proba(X_test)[:, 1]
control_proba_test = control_pipeline.predict_proba(X_test)[:, 1]

# %%
uplift_test = control_proba_test - treatment_proba_test
predicted_uplift_test = pd.DataFrame({
    MEMBER_ID_COLUMN: features_with_labels.loc[X_test.index, MEMBER_ID_COLUMN].values,
    "uplift": uplift_test
})

predicted_uplift_test
# Out:
#       member_id    uplift
# 0          6164 -0.044115
# 1          2695 -0.098283
# 2          4206  0.248988
# 3          4958 -0.203562
# 4          6099 -0.251917
# ...         ...       ...
# 1986       6506  0.083145
# 1987       3789 -0.137656
# 1988       8396 -0.016786
# 1989       8825  0.225799
# 1990       7428 -0.252697
#
# [1991 rows x 2 columns]

# %%
predicted_uplift_test = pd.DataFrame({
    MEMBER_ID_COLUMN: features_with_labels.loc[X_test.index, MEMBER_ID_COLUMN].values,
    "uplift": uplift_test
})
predicted_uplift_test.sort_values(by='uplift', ascending=False, inplace=True)

predicted_uplift_test
# Out:
#       member_id    uplift
# 1163        234  0.582433
# 20         8460  0.561834
# 1037        297  0.549649
# 271        6247  0.522922
# 693        2869  0.516404
# ...         ...       ...
# 1788       9147 -0.506332
# 254        5081 -0.507495
# 925        9080 -0.533882
# 1623       8345 -0.537816
# 1027       9682 -0.661256
#
# [1991 rows x 2 columns]

# %%
treatment_proba_all = treatment_pipeline.predict_proba(X)[:, 1]
control_proba_all = control_pipeline.predict_proba(X)[:, 1]

# %%
uplift_all = control_proba_all - treatment_proba_all

# %%
predicted_uplift_all = pd.DataFrame({
    MEMBER_ID_COLUMN: features_with_labels[MEMBER_ID_COLUMN],
    "uplift": uplift_all
})
predicted_uplift_all.sort_values(by='uplift', ascending=False, inplace=True)
predicted_uplift_all = predicted_uplift_all.copy()
predicted_uplift_all['rank'] = np.arange(1, len(predicted_uplift_all) + 1)
predicted_uplift_all.rename(columns={'uplift': 'prioritization_score'}, inplace=True)

predicted_uplift_all
# Out:
#       member_id  prioritization_score  rank
# 439         444              0.615820     1
# 3663       3686              0.593763     2
# 232         234              0.582433     3
# 8414       8460              0.561834     4
# 294         297              0.549649     5
# ...         ...                   ...   ...
# 7193       7230             -0.600433  9949
# 8635       8682             -0.614717  9950
# 5499       5528             -0.649426  9951
# 9634       9682             -0.661256  9952
# 5791       5822             -0.674040  9953
#
# [9953 rows x 3 columns]

# %% [markdown]
# ## Optimal N

# %% [markdown]
# ### Same Budget Optimized

# %% [markdown]
# ### Optimizing N without Budget Limit

# %%
order_test = np.argsort(-uplift_test)
y_ordered_test = y_test.values[order_test]
t_ordered_test = t_test.values[order_test]

cumulative_treatment_test = (t_ordered_test == 1).astype(int).cumsum()

y_retention_ordered_test = (1 - y_ordered_test)
cumulative_retention_treatment_test = ((t_ordered_test == 1) & (y_retention_ordered_test == 1)).astype(int).cumsum()
control_retention_rate = (
    ((t_ordered_test == 0) & (y_retention_ordered_test == 1)).sum()
    / max((t_ordered_test == 0).sum(), 1)
)
qini = cumulative_retention_treatment_test - control_retention_rate * cumulative_treatment_test

optimal_n = int(np.argmax(qini)) + 1
optimal_k_percent = 100 * optimal_n / len(qini)

print(f"Optimal n (count): {optimal_n}")
print(f"Optimal k (% of population): {optimal_k_percent:.2f}%")
print(f"Qini @ optimal n: {qini[optimal_n - 1]:.2f}")
# Out:
# Optimal n (count): 1249
# Optimal k (% of population): 62.73%
# Qini @ optimal n: 11.93

# %%
ltv_per_member = 85.0              # USD — average lifetime value per retained wellness app user
sms_cost = 0.045                   # USD — Twilio per-SMS (domestic average, ~0.04–0.06)
email_cost = 0.002                 # USD — via SendGrid or similar
short_zoom_video_call_cost = 1.80  # USD — ~10-min call with a wellness coach at $10–12/hr equivalent
short_phone_call_cost = 1.20       # USD — ~8-min outbound retention call center rate (~$9/hr)

outreach_costs_to_evaluate = [sms_cost, email_cost, short_zoom_video_call_cost, short_phone_call_cost]

# %%
for v in [ltv_per_member]:
    for c in outreach_costs_to_evaluate:
        uplift_sorted_all = np.sort(uplift_all)[::-1]
        net_curve = np.cumsum(v * uplift_sorted_all - c)
        optimal_n = int(np.argmax(net_curve)) + 1
        print(f"Optimal n considering cost {c} = {optimal_n}")

        fig = go.Figure()
        fig.add_trace(go.Scatter(
            x=np.arange(1, len(net_curve) + 1),
            y=net_curve,
            mode='lines',
            name='Cumulative Net Value',
            line=dict(width=2)
        ))
        fig.add_vline(
            x=optimal_n,
            line_dash="dash",
            line_color="red",
            annotation_text=f"Optimal n = {optimal_n}",
            annotation_position="top right"
        )
        fig.update_layout(
            title=f"Net Value vs. n (Cost = {c}, Value per uplift unit = {v})",
            title_x=0.5,
            xaxis_title="Number of Members Outreached (sorted by uplift)",
            yaxis_title="Cumulative Net Value (USD)",
            template="plotly_white",
        )
        fig.show()
# Out:
# Optimal n considering cost 0.045 = 5021
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="cfd45649-50ce-469b-9ebe-bb56de4c2fcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cfd45649-50ce-469b-9ebe-bb56de4c2fcf")) {                    Plotly.newPlot(                        "cfd45649-50ce-469b-9ebe-bb56de4c2fcf",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...
# Optimal n considering cost 0.002 = 5030
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="e5e53653-1e5a-4beb-9013-1696524afb32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e5e53653-1e5a-4beb-9013-1696524afb32")) {                    Plotly.newPlot(                        "e5e53653-1e5a-4beb-9013-1696524afb32",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...
# Optimal n considering cost 1.8 = 4532
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="be74948c-8761-4689-b597-c46f0b08338e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("be74948c-8761-4689-b597-c46f0b08338e")) {                    Plotly.newPlot(                        "be74948c-8761-4689-b597-c46f0b08338e",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...
# Optimal n considering cost 1.2 = 4685
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="eef57ab4-b7d2-404d-8dcc-9c5198dbebe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eef57ab4-b7d2-404d-8dcc-9c5198dbebe4")) {                    Plotly.newPlot(                        "eef57ab4-b7d2-404d-8dcc-9c5198dbebe4",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...

# %%
fig = go.Figure()

# Main cumulative uplift line
fig.add_trace(go.Scatter(
    x=np.arange(1, len(cum_gain_all) + 1),
    y=cum_gain_all,
    mode='lines',
    line=dict(width=2, color='rgba(0,102,204,0.9)'),
    name='Cumulative Uplift',
    hovertemplate='Members Reached: %{x}<br>Cumulative Uplift: %{y:.2f}<extra></extra>'
))

# Optimal n vertical line
fig.add_vline(
    x=optimal_n,
    line_dash="dash",
    line_color="red",
    annotation_text=f"Optimal n = {optimal_n}",
    annotation_position="top right"
)

# Layout styling
fig.update_layout(
    title=dict(
        text="Cumulative Uplift Curve (Optimal n Highlighted)",
        x=0.5,
        xanchor="center",
        font=dict(size=20, family="Arial Black")
    ),
    xaxis_title="Number of Members (sorted by uplift)",
    yaxis_title="Cumulative Expected Retention Gain",
    template="plotly_white",
    showlegend=False
)

fig.update_xaxes(showgrid=True, gridcolor='lightgray', zeroline=False)
fig.update_yaxes(showgrid=True, gridcolor='lightgray', zeroline=False)

fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="6cc35948-6e6b-494f-bae4-109e71602626" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6cc35948-6e6b-494f-bae4-109e71602626")) {                    Plotly.newPlot(                        "6cc35948-6e6b-494f-bae4-109e71602626",                        [{"hovertemplate":"Members Reached: %{x}\u003cbr\u003eCumulative Uplift: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"rgba(0,102,204,0.9)","width":2},"mode":"lines","name":"Cumulative Uplift","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwg ...

# %%
for v in [20]:
    for c in [1, 0.06, 0.006, 0.6]:
        uplift_sorted_all = np.sort(uplift_all)[::-1]
        net_curve = np.cumsum(v * uplift_sorted_all - c)
        optimal_n = int(np.argmax(net_curve)) + 1
        print(f"Optimal n considering cost = {optimal_n}")

        fig = go.Figure()
        fig.add_trace(go.Scatter(
            x=np.arange(1, len(net_curve) + 1),
            y=net_curve,
            mode='lines',
            name='Cumulative Net Value',
            line=dict(width=2)
        ))
        fig.add_vline(
            x=optimal_n,
            line_dash="dash",
            line_color="red",
            annotation_text=f"Optimal n = {optimal_n}",
            annotation_position="top right"
        )
        fig.update_layout(
            title=f"Net Value vs. n (Cost = {c}, Value per uplift unit = {v})",
            title_x=0.5,
            xaxis_title="Number of Members Outreached (sorted by uplift)",
            yaxis_title="Cumulative Net Value (USD)",
            template="plotly_white",
        )
        fig.show()
# Out:
# Optimal n considering cost = 3905
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="538e80d1-7c8d-44ef-8c71-398258e4f7d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("538e80d1-7c8d-44ef-8c71-398258e4f7d2")) {                    Plotly.newPlot(                        "538e80d1-7c8d-44ef-8c71-398258e4f7d2",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...
# Optimal n considering cost = 4971
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="4902ad2c-0ff1-45f1-9e4c-394adccdeb60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4902ad2c-0ff1-45f1-9e4c-394adccdeb60")) {                    Plotly.newPlot(                        "4902ad2c-0ff1-45f1-9e4c-394adccdeb60",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...
# Optimal n considering cost = 5028
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="a8491dee-31a8-41c7-add0-904b016e7a9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a8491dee-31a8-41c7-add0-904b016e7a9b")) {                    Plotly.newPlot(                        "a8491dee-31a8-41c7-add0-904b016e7a9b",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...
# Optimal n considering cost = 4346
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="2bdaec3a-ebbd-44c8-8260-d3f5212a9498" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2bdaec3a-ebbd-44c8-8260-d3f5212a9498")) {                    Plotly.newPlot(                        "2bdaec3a-ebbd-44c8-8260-d3f5212a9498",                        [{"line":{"width":2},"mode":"lines","name":"Cumulative Net Value","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwgYCBkIGggbCBwIHQgeCB8IIAghCCIIIwgkCCUIJggnCCgIKQgqCCsILAgtCC4ILwgwCDEIMggzCDQINQg2CDcIOAg5CDoIOwg8CD0IPgg\...\u002fgj\...\u002fCcAJwQnCCcMJxAnFCcYJxw ...

# %%
best_net_value = net_curve[optimal_n - 1]
roi = best_net_value / (c * optimal_n) if c * optimal_n > 0 else float('inf')
print(f"[Cost={c}, Value={v}] ROI at optimal n: {roi:.2f}x | Expected net gain: ${best_net_value:.2f}")

y_retention_test = 1 - y_test
y_retention_train = 1 - y_train_m
# Out:
# [Cost=0.6, Value=20] ROI at optimal n: 4.32x | Expected net gain: $11257.27

# %%
baseline_xgb_params = dict(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    random_state=42,
    n_jobs=-1,
    eval_metric='logloss'
)

treatment_pipeline = make_pipeline(
    StandardScaler(),
    XGBClassifier(**baseline_xgb_params)
)

control_pipeline = make_pipeline(
    StandardScaler(),
    XGBClassifier(**baseline_xgb_params)
)

uplift_model = TwoModels(
    estimator_trmnt=treatment_pipeline,
    estimator_ctrl=control_pipeline,
    method='vanilla'
)

# %%
uplift_model.fit(X_train_m, y_retention_train, treatment=t_train_m)
uplift_predictions_test = uplift_model.predict(X_test)
uplift_predictions_all = uplift_model.predict(X)
uplift_predictions_train_m = uplift_model.predict(X_train_m)

uplift_train_full = np.full(len(X_train), np.nan, dtype=float)
uplift_train_full[matched_idx_train] = uplift_predictions_train_m

# %%
uplift_predictions_test
# Out:
# array([ 0.01349241,  0.14032394,  0.28399533, ...,  0.22396475,
#         0.18719316, -0.11137027], shape=(1991,), dtype=float32)

# %%
qini_area = qini_auc(y=y_test.values, t=t_test.values, uplift_scores=uplift_predictions_test)
print(f"Qini AUC (Two-Model XGB, test): {qini_area:,.2f}")
# Out:
# Qini AUC (Two-Model XGB, test): -4,853.61

# %%
print("AUC:", roc_auc_score(y_test, y_proba))

# %%
sorted_indices_all = np.argsort(-uplift_all)
uplift_sorted_all = uplift_all[sorted_indices_all]
cum_gain_all = np.cumsum(uplift_sorted_all)

optimal_n = int(np.argmax(cum_gain_all)) + 1
actual_n = optimal_n
budget_n = 3959
print(f"Final optimal n = {optimal_n}")
print(f"Using actual n = {actual_n}")
# Out:
# Final optimal n = 5031
# Using actual n = 5031

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=np.arange(1, len(cum_gain_all) + 1),
    y=cum_gain_all,
    mode='lines',
    line=dict(width=2, color='rgba(0,102,204,0.9)'),
    name='Cumulative Uplift',
    hovertemplate='Members Reached: %{x}<br>Cumulative Uplift: %{y:.2f}<extra></extra>'
))
fig.add_vline(
    x=optimal_n,
    line_dash="dash",
    line_color="green",
    annotation_text=f"Optimal n = {optimal_n}",
    annotation_position="top right"
)
fig.add_vline(
    x=budget_n,
    line_dash="dash",
    line_color="blue",
    annotation_text=f"Budget n = {budget_n}",
    annotation_position="top right"
)
fig.update_layout(
    title=dict(
        text="Cumulative Uplift Curve (Optimal n Highlighted)",
        x=0.5,
        xanchor="center",
        font=dict(size=20, family="Arial Black")
    ),
    xaxis_title="Number of Members (sorted by uplift)",
    yaxis_title="Cumulative Expected Retention Gain",
    template="plotly_white",
    showlegend=False
)
fig.update_xaxes(showgrid=True, gridcolor='lightgray', zeroline=False)
fig.update_yaxes(showgrid=True, gridcolor='lightgray', zeroline=False)

fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="8f839887-6d38-46df-950a-21731c4d5a49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8f839887-6d38-46df-950a-21731c4d5a49")) {                    Plotly.newPlot(                        "8f839887-6d38-46df-950a-21731c4d5a49",                        [{"hovertemplate":"Members Reached: %{x}\u003cbr\u003eCumulative Uplift: %{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"rgba(0,102,204,0.9)","width":2},"mode":"lines","name":"Cumulative Uplift","x":{"dtype":"i2","bdata":"...\u002fAMAAwQDCAMMAxADFAMYAxwDIAMkAygDLAMwAzQDOAM8A0ADRANIA0wDUANUA1gDXANgA2QDaANsA3ADdAN4A3wDgAOEA4gDjAOQA5QDmAOcA6ADpAOoA6wDsAO0A7gDvAPAA8QDyAPMA9AD1APYA9wD4APkA+gD7APwA\\\u002fAH9Af4B\u002fwEAAgECAgIDAgQCBQIGAgcCCAIJAgoCCwIMAg0CDgIPAhACEQISAhMCFAIVAhYCFwIYAhkCGgIbAhwCHQIeAh8CIAIhAiICIwIkAiUCJgInAigCKQIqAisCLAItAi4CLwIwAjECMgIzAjQCNQI2AjcCOAI5AjoCOwI8Aj0CPgI\...\u002fgL\...\u002fA8ADwQPCA8MDxAPFA8YDxwPIA8kDygPLA8wDzQPOA88D0APRA9ID0wPUA9UD1gPXA9gD2QPaA9sD3APdA94D3wPgA+ED4gPjA+QD5QPmA+cD6APpA+oD6wPsA+0D7gPvA\u002fAD8QPyA\u002fMD9AP1A\u002fYD9wP4A\u002fkD+gP7A\u002fwD\u002fQP+A\\\u002fAT9BP4E\u002fwQABQEFAgUDBQQFBQUGBQcFCAUJBQoFCwUMBQ0FDgUPBRAFEQUSBRMFFAUVBRYFFwUYBRkFGgUbBRwFHQUeBR8FIAUhBSIFIwUkBSUFJgUnBSgFKQUqBSsFLAUtBS4FLwUwBTEFMgUzBTQFNQU2BTcFOAU5BToFOwU8BT0FPgU\...\u002fgX\...\u002fBsAGwQbCBsMGxAbFBsYGxwbIBskGygbLBswGzQbOBs8G0AbRBtIG0wbUBtUG1gbXBtgG2QbaBtsG3AbdBt4G3wbgBuEG4gbjBuQG5QbmBucG6AbpBuoG6wbsBu0G7gbvBvAG8QbyBvMG9Ab1BvYG9wb4BvkG+gb7BvwG\\\u002fIH8wf0B\u002fUH9gf3B\u002fgH+Qf6B\u002fsH\u002fAf9B\u002f4H\u002fwcACAEIAggDCAQIBQgGCAcICAgJCAoICwgMCA0IDggPCBAIEQgSCBMIFAgVCBYIFwg ...
